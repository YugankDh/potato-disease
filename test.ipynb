# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.models.load_model("100epochspotato.keras")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.export("model/1")
# Out:
# INFO:tensorflow:Assets written to: model/1\assets
# INFO:tensorflow:Assets written to: model/1\assets
# Saved artifact at 'model/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   2452058098192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058099152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058099344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058100880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058102416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058103184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058102032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058103376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058102224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058103760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058102800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058104528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058103952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058105296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058105104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058105680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058104144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058105872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058104912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2452058106256: TensorSpec(shape=(), dtype=tf.resource, name=None)
